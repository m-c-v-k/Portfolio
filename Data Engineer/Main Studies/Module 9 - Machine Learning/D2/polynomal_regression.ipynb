# %%
import numpy as np
x = np.array([0,1,2,3,4,5])
y = np.array([8,0,0.1,-0.8,-1, 4])
print(x)
print(y)

p1 = np.polyfit(x,y,1)
p2 = np.polyfit(x,y,2)
p3 = np.polyfit(x,y,3)

print(p1)
print(p2)
print(p3)
# Out:
# [0 1 2 3 4 5]
# [ 8.   0.   0.1 -0.8 -1.   4. ]
# [-0.68285714  3.42380952]
# [ 1.13928571 -6.37928571  7.22142857]
# [-0.08703704  1.79206349 -7.57169312  7.48253968]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x, y, 'o')
xp = np.linspace(-2,6,100)
plt.plot(xp,np.polyval(p1,xp), 'r-')
plt.plot(xp,np.polyval(p2,xp), 'b--')
plt.plot(xp,np.polyval(p3,xp), 'm:')
yfit = p1[0] * x + p1[1]
yresid = y - yfit
SSresid = np.sum(yresid**2)
SStotal = len(y) * np.var(y)
rsq = 1 - SSresid /SStotal
print(yfit)
print(y)
print(rsq)
# Out:
# [3.42380952 2.74095238 2.05809524 1.3752381  0.69238095 0.00952381]
# [ 8.   0.   0.1 -0.8 -1.   4. ]
# 0.127565350415198

# %%
from scipy.stats import linregress
slope, intercept, r_value, p_value, std_err = linregress(x,y)
print(r_value)
print(p_value)
plt.show()
# Out:
# -0.3571629185892594
# 0.4870364285486879
